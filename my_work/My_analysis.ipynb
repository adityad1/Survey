# %%
import pandas as pd
df = pd.read_csv('../datasets/Clean_survey.csv')
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as mplstyle
mplstyle.use(['bmh','fast','seaborn-dark-palette'])

# %% [markdown]
# Importing all required libraries, the csv file, stylizing our plots, etc.

# %% [markdown]
# ## Year

# %%
count, ax = plt.subplots()
ax = sns.countplot(x = 'Year', data = df)
ax.set_title('Number of responses from each year')
ax.set_xlabel('Year')
ax.set_ylabel('Number of students')
# Out:
# Text(0, 0.5, 'Number of students')

# %% [markdown]
# There's a gradual drop from 2nd year to the 3rd year implying that students decide or know which field of expertise they belong to by that time.

# %% [markdown]
# ## Excitement

# %%
violin, ax = plt.subplots(figsize = (6,9))
ax = sns.violinplot(y = 'Excitement_scale', data = df)
ax.set_ylabel('Excitement_Scale(1-10)')
ax.set_title("A violin plot describing the excitement of \n students on hearing the term 'Data Science'.")
# Out:
# Text(0.5, 1.0, "A violin plot describing the excitement of \n students on hearing the term 'Data Science'.")

# %% [markdown]
# For those of you who don't know what a violin plot is, it is just a boxplot with density included and slightly giving outliers some cover to hide under.
# Percentiles are uniformly spread at the top with 8 at 25%, 9 at 50%, 10 at 75% and 100% which means most students totally take 'Data Science' as a super hero.
# Overall this violin plot gives us a sense that most students get excited to the brim when they hear the term 'Data Science'.

# %% [markdown]
# ## How excited are students across years

# %%
fig, ax = plt.subplots(figsize = (10,8))
ax = sns.countplot(y = 'Excitement_scale', hue = 'Year', data = df)
ax.legend(loc = 1)
ax.set_title('Excitement of students across years')
ax.set_xlabel('Number of students')
ax.set_ylabel('Scale(1-10)')
# Out:
# Text(0, 0.5, 'Scale(1-10)')

# %% [markdown]
# We see two tall blue lines representing the first years with an excitement at scale 9 and 10 implying that first years are trying to explore fields one of which is 'Data Science'.
# We see a tall green line at excitement scale 8 representing second years who are not too sure on 'Data Science' yet.
# All the fourth years have an excitement scale above 7 giving a sense of the statement made earlier that all the fourth years have decided their field of expertise which they will be considering. All the other fourth years didn't bother to take the survey. Same goes with third years in a bit smaller scale.

# %% [markdown]
# ## Holidays

# %%
count, ax = plt.subplots()
ax = sns.countplot(y = 'Holidays', data = df)
ax.set_title('This is what suits students best in holidays.')
ax.set_xlabel('Number of students')
ax.set_ylabel('Work done by the students')
# Out:
# Text(0, 0.5, 'Work done by the students')

# %% [markdown]
# Majority of our students are learning python or data science. -  (46)
# A few are not interested while another few are working on projects. - (4)
# A major part of our students is also stuck with other work and unable to work on data science. - (18)

# %% [markdown]
# ## Learning Python

# %%
Py = pd.read_csv('../datasets/Py_learn.csv')

# %%
Py['0'].value_counts()
# Out:
# Google          37
# Winter Codex    16
# Solo learn      14
# Others          11
# Udemy            8
# Youtube          7
# Real python      5
# Codecademy       4
# Name: 0, dtype: int64

# %% [markdown]
# The attribute had multiple entries which were separated by a comma.So, I made a list of the seperated values which i later converted to a Series object in pandas to use various functions of pandas upon these.
# For plotting, I'm considering all the values which have a frequency more then two and making all the other objects as 'Others'.
# And also renaming the first two as Winter Codex and Google.

# %%
bar, ax = plt.subplots()
ax = sns.countplot(y = '0', data = Py)
ax.set_title('Learning Python')
ax.set_ylabel('Sources')
ax.set_xlabel('Number of students')
# Out:
# Text(0.5, 0, 'Number of students')

# %% [markdown]
# Most students learn python from Google. - (37 students)
# Youtube is also pretty popular due to real python in visual format leading to saving time and stuff. - (7 students)
# Winter codex is the second most popular source to learn python because all the basic essentials are in a single place and nicely documented too. - (16 students)
# Few of the lot is also going through the codes on real time or also learning by themselves. - (19 students)
# All the others are learning through online courses through various websites like Udemy, Codcademy etc. - (23 students)

# %% [markdown]
# ## Who knows about the SIG

# %%
sig, ax = plt.subplots()
ax = sns.countplot(y = 'SIG_Aware', data = df)
ax.set_title('Are students aware of the DS SIG?')
ax.set_xlabel('Number of students')
ax.set_ylabel('Opinion')
# Out:
# Text(0, 0.5, 'Opinion')

# %% [markdown]
# 41 students are aware that there is an SIG in the college.
# 25 students don't know that there is an SIG in the college which is pretty sad.
# Also, 3 great souls know that there is a NAMESAKE DS SIG in the college.

# %% [markdown]
# ## Winter Codex

# %%
w, ax = plt.subplots()
ax = sns.countplot(x = 'Winter_codex_aware', data = df)
ax.set_title('Do the students know about the Winter CodeX?')
ax.set_xlabel('Opinion')
ax.set_ylabel('Number of students')
# Out:
# Text(0, 0.5, 'Number of students')

# %% [markdown]
# A good amount of student know about the Winter CodeX.

# %% [markdown]
# ## Learning Preference

# %%
c, ax = plt.subplots()
ax = sns.countplot(y = 'Learning_preference', data = df)
ax.set_title('How do students like to learn?')
ax.set_ylabel('Option')
ax.set_xlabel('Number of students')
# Out:
# Text(0.5, 0, 'Number of students')

# %% [markdown]
# Most of the student prefer learning through working on a project. - (38 students)
# The next major group prefer online courses. - (23 students)
# Few students like reading. - (7 students)
# One great soul believes god will teach him.

# %% [markdown]
# ## How serious are students on DS

# %%
s, ax = plt.subplots(figsize = (6,9))
ax = sns.violinplot(y = 'Career_seriousness_scale', data = df)
ax.set_title('Seriousness on DS')
ax.set_xlabel('Density of students')
ax.set_ylabel('Scale(1-10)')
# Out:
# Text(0, 0.5, 'Scale(1-10)')

# %% [markdown]
# The plot shows us that seriousness of students on a career in 'Data Science' slides down gradually.
# And also the upper percentile above 8 shows us that more than half of the students are serious about a career in 'Data Science'.

# %% [markdown]
# ## Are students scared of maths?

# %%
m, ax = plt.subplots(figsize = (6,9))
ax = sns.violinplot(y = 'Math_stat_fear', data = df)
ax.set_title('Fear on Maths and Stats')
ax.set_xlabel('Density of students')
ax.set_ylabel('Scale(1-10)')
# Out:
# Text(0, 0.5, 'Scale(1-10)')

# %% [markdown]
# Don't feel the graph is wrong because you see a value 12 which is out of index. The small black line inside ending at 10 implies that 10 is the maximum value taken by any student.
# We have a nice amount of density between 6 and 8 implying that there are students who are scared of maths and statistics.
# We get a diverse plot implying that most students are moderately scared of maths and statistics.

# %% [markdown]
# ## Have students worked on DS projects?

# %%
p, ax = plt.subplots(figsize = (6,9))
ax = sns.countplot(x = 'Projects', data = df)
ax.set_title('Did students work on DS projects?')
ax.set_xlabel('Opinion')
ax.set_ylabel('Number of students')
# Out:
# Text(0, 0.5, 'Number of students')

# %% [markdown]
# Only 9 students have worked on an actual Data Science project.

# %% [markdown]
# ## E-Mail IDs

# %%
em, ax = plt.subplots()
ax = sns.countplot(y = 'SS', data = df)
ax.set_title('How do students feel about E-Mail?')
ax.set_xlabel('Number of students')
ax.set_ylabel('Opinion')
# Out:
# Text(0, 0.5, 'Opinion')

# %% [markdown]
# 51 students agree that the SIG wouldn't spam their E-Mails.
# 19 students feel its a scam and do not enter their E-Mails.
